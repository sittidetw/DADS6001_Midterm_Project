# %% [markdown]
# <a href="https://colab.research.google.com/github/sittidetw/dads5001_midterm_project/blob/main/EDA_HIV_Proactive_Screening.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Demographic and Spatial Factors to Enhance Proactive HIV Screening Efficiency

# %%
# !git clone https://github.com/sittidetw/dads5001_midterm_project.git
# Out:
# Cloning into 'dads5001_midterm_project'...
# remote: Enumerating objects: 220, done.
# remote: Counting objects: 100% (67/67), done.
# remote: Compressing objects: 100% (42/42), done.
# remote: Total 220 (delta 48), reused 25 (delta 25), pack-reused 153 (from 1)
# Receiving objects: 100% (220/220), 3.77 MiB | 22.07 MiB/s, done.
# Resolving deltas: 100% (76/76), done.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.patches as mpatches
import matplotlib.lines as mlines
import seaborn as sns

# %%
# Load the Data (Wide Format)
file_path = '/content/dads5001_midterm_project/prep_data/hiv_pop.xlsx'
try:
    df = pd.read_excel(file_path)
    print("Data loaded successfully. Shape:", df.shape)
    str_cols = df.columns[:9]
    float_cols = df.columns[9:]
    df[str_cols] = df[str_cols].astype('string')
    df[float_cols] = df[float_cols].astype('float64')
    display(df.info())
except FileNotFoundError:
    print(f"File not found at {file_path}. Please upload the file to colab.")
# Out:
# Data loaded successfully. Shape: (770, 55)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 770 entries, 0 to 769
# Data columns (total 55 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   year                     770 non-null    string
#  1   health_region            770 non-null    string
#  2   province_th              770 non-null    string
#  3   health_region_desc_th    770 non-null    string
#  4   region_th                770 non-null    string
#  5   province                 770 non-null    string
#  6   health_region_desc       770 non-null    string
#  7   region                   770 non-null    string
#  8   sex                      770 non-null    string
#  9   test_fsw                 770 non-null    float64
#  10  test_migrant             770 non-null    float64
#  11  test_msm                 770 non-null    float64
#  12  test_msw                 770 non-null    float64
# ...

# %%
# Load the Data (Long Format)
file_path_long = '/content/dads5001_midterm_project/prep_data/hiv_pop_long.xlsx'
try:
    df_long = pd.read_excel(file_path_long)
    print("Data loaded successfully. Shape:", df_long.shape)
    str_cols = df_long.columns[:11]
    float_cols = df_long.columns[11:]
    df_long[str_cols] = df_long[str_cols].astype('string')
    df_long[float_cols] = df_long[float_cols].astype('float64')
    display(df_long.info())
except FileNotFoundError:
    print(f"File not found at {file_path}. Please upload the file to colab.")
# Out:
# Data loaded successfully. Shape: (7700, 15)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7700 entries, 0 to 7699
# Data columns (total 15 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   year                   7700 non-null   string
#  1   health_region          7700 non-null   string
#  2   province_th            7700 non-null   string
#  3   health_region_desc_th  7700 non-null   string
#  4   region_th              7700 non-null   string
#  5   province               7700 non-null   string
#  6   health_region_desc     7700 non-null   string
#  7   region                 7700 non-null   string
#  8   sex                    7700 non-null   string
#  9   group                  7700 non-null   string
#  10  population             7700 non-null   string
#  11  test                   7700 non-null   float64
#  12  positive               7700 non-null   float64
# ...

# %% [markdown]
# # ภาพรวมระดับประเทศ

# %%
# @title-
yearly_cols = df_long.columns[11:]
yearly_totals = df_long.groupby('year')[yearly_cols].sum()
yearly_totals.index = yearly_totals.index.astype(int)
yearly_totals['Positivity Rate'] = (yearly_totals['positive'] / yearly_totals['test']) * 100

# สร้างตัวแปรสำหรับ Plot (หารล้าน)
test_total_m = yearly_totals['test'] / 1e6

fig, ax1 = plt.subplots(figsize=(12, 6), dpi=150)

# 1. วาดกราฟแท่ง (Total Tests)
ax1.bar(yearly_totals.index, test_total_m,
        color='#f0f2f5', label='Total Tests', edgecolor='#bdc3c7', width=0.7)

# ปรับแต่งแกน Y ฝั่งซ้าย
ax1.set_xlabel('Year', fontsize=13, fontweight='normal')
ax1.set_ylabel('Total Tests (Millions)', fontsize=13, fontweight='normal')
ax1.set_xticks(yearly_totals.index)
ax1.set_ylim(0, test_total_m.max() * 1.2) # เผื่อที่ด้านบนสำหรับ Label

# 2. สร้างแกน Y ที่สอง สำหรับ Positivity Rate
ax2 = ax1.twinx()
ax2.plot(yearly_totals.index, yearly_totals['Positivity Rate'],
         marker='o', markersize=8, label='Positivity Rate', color='#0000FF', linewidth=2) #linestyle='--', #2c3e50

# ปรับแต่งแกน Y ฝั่งขวา
ax2.set_ylabel('Positivity Rate (%)', fontsize=13, color='#0000FF', fontweight='normal') #2c3e50
ax2.set_ylim(0, yearly_totals['Positivity Rate'].max() * 2.75) # ปรับให้เส้นกราฟอยู่ช่วงกลาง
#ax2.tick_params(axis='y', labelcolor='#2c3e50')
ax2.tick_params(axis='y', labelcolor='#0000FF')
ax2.spines['right'].set_color('#0000FF')

# 4. การตกแต่ง (Styling)
plt.title('Thailand HIV Testing Strategic Trend (2021-2025)',
          fontsize=16, pad=20, fontweight='bold')
ax1.grid(True, axis='y', linestyle='--', alpha=0.3)
#ax1.spines['top'].set_visible(False)
#ax2.spines['top'].set_visible(False)

# 5. ใส่ตัวเลขกำกับ (Annotations)
# ตัวเลข Total Tests (ด้านบนแท่ง)
for x, y_m, y_real in zip(yearly_totals.index, test_total_m, yearly_totals['test']):
    ax1.text(x, y_m + 0.05, f'Total: {int(y_real):,}',
             ha='center', fontsize=10, fontweight='normal') #, color='#7f8c8d'

# ตัวเลข Positive Cases (วางไว้ที่ฐานแท่ง)
for x in yearly_totals.index:
    pos_val = int(yearly_totals.loc[x, 'positive'])
    ax1.text(x, 0.05, f'Positives:\n{pos_val:,}',
             ha='center', va='bottom', fontsize=10, fontweight='normal') #, color='#d35400'

# ตัวเลข % (บนจุดของเส้น)
for x, y in zip(yearly_totals.index, yearly_totals['Positivity Rate']):
    ax2.annotate(f'{y:.2f}%', (x, y), textcoords="offset points", xytext=(0, 12),
                 ha='center', fontweight='bold', color='#0000FF', fontsize=11)

# 6. สร้าง Legend
grey_patch = mpatches.Patch(color='#f0f2f5', label='Total Tests (Bar)')
blue_line = mlines.Line2D([], [], color='#0000FF', marker='o', label='Positivity Rate (%)') #linestyle='--', #2c3e50

ax1.legend(handles=[grey_patch, blue_line], loc='upper left', bbox_to_anchor=(1.05, 1), frameon=True)

plt.tight_layout()
plt.savefig('f1_Thailand HIV Testing Strategic Trend (2021-2025)', bbox_inches='tight')
plt.show()

# %% [markdown]
# ตีความได้ 2 แบบ
# 1. โฟกัสถูกกลุ่มไหม
# อธิบายเรื่องเพศ และกลุ่มประชากร ให้ recommendation ว่าควรโฟกัสกลุ่ม ผญ. ยังไง
# 2. กักกันโรคได้ดีแล้ว เพราะจำนวนผู้ติดเชื้อไม่ได้เพิ่มขึ้นตามจำนวนผู้ตรวจ
# อธิบายเชิงพื้นที่ ว่าภาคไหนเสี่ยงไม่เสี่ยง ลงรายจังหวัด แล้วจบด้วยการโฟกัส high yield.. ให้รายชื่อจังหวัดที่ต้องโฟกัส และทำ resource reallocation

# %% [markdown]
# ---
# ## ข้อ 1: ภาพรวมและช่องว่างของข้อมูล (Overall Positivity Rate & KPs vs Other)
# ตรวจสอบอัตราการตรวจพบเชื้อในภาพรวม และเปรียบเทียบระหว่างกลุ่ม Key Populations (KPs) และกลุ่มคนทั่วไป (Other)

# %%
# 1. จัดกลุ่มข้อมูลตามปี และรวมยอดผู้ติดเชื้อ KPs กับ Others
yearly_data = df.groupby('year')[['positive_all_kps', 'positive_others']].sum()

# 2. คำนวณเป็นสัดส่วนเปอร์เซ็นต์ (Normalization to 100%)
yearly_prop = yearly_data.div(yearly_data.sum(axis=1), axis=0) * 100

# 3. สร้างกราฟ Stacked Bar Chart
ax = yearly_prop.plot(kind='bar',
                      stacked=True,
                      figsize=(10, 6),
                      color=['#ff9999', '#66b3ff'],
                      width=0.6)

# --- ส่วนของการเปลี่ยนรายละเอียดกราฟเป็นภาษาอังกฤษ (Graph Details in English) ---

# ตั้งชื่อหัวข้อและแกน
plt.title('Annual Proportion of HIV Positive Cases: KPs vs. Others (2021-2025)', fontsize=15, pad=20)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Proportion Percentage (%)', fontsize=12)

# ปรับชื่อ Legend (คำอธิบายสัญลักษณ์)
plt.legend(['Key Populations (KPs)', 'General Population (Others)'],
           loc='upper center',
           bbox_to_anchor=(0.5, -0.15),
           ncol=2)

# ใส่ตัวเลข % กำกับบนแท่งกราฟ
for p in ax.patches:
    width, height = p.get_width(), p.get_height()
    x, y = p.get_xy()
    if height > 0: # แสดงตัวเลขเฉพาะเมื่อมีค่ามากกว่า 0
        ax.text(x + width/2,
                y + height/2,
                f'{height:.1f}%',
                ha='center',
                va='center',
                fontsize=11,
                fontweight='bold',
                color='white')

plt.xticks(rotation=0) # ให้ปีแสดงผลในแนวตั้งปกติ
plt.tight_layout()
plt.show()

# %%
# 1. เตรียมข้อมูล Positivity Rate แยกตามปี เพศ และกลุ่มประชากร
# จัดกลุ่มข้อมูลรายปีและเพศ
yearly_gender_summary = df.groupby(['year', 'sex']).sum().reset_index()

# สร้าง DataFrame ใหม่สำหรับพล็อตโดยคำนวณ Rate แยกเป็น KPs และ Others
rows = []
for _, row in yearly_gender_summary.iterrows():
    # คำนวณของกลุ่ม KPs
    kp_rate = (row['positive_all_kps'] / row['test_all_kps'] * 100) if row['test_all_kps'] > 0 else 0
    rows.append({'Year': row['year'], 'Gender': row['sex'].capitalize(),
                 'Population_Group': 'Key Populations (KPs)', 'Positivity_Rate': kp_rate})

    # คำนวณของกลุ่ม Others
    others_rate = (row['positive_others'] / row['test_others'] * 100) if row['test_others'] > 0 else 0
    rows.append({'Year': row['year'], 'Gender': row['sex'].capitalize(),
                 'Population_Group': 'Others', 'Positivity_Rate': others_rate})

plot_df = pd.DataFrame(rows)

# 2. สร้างกราฟแยกตามเพศเป็น 2 บรรทัด (FacetGrid)
sns.set_theme(style="whitegrid")
g = sns.catplot(
    data=plot_df,
    x='Year',
    y='Positivity_Rate',
    hue='Population_Group',
    row='Gender',
    row_order=['Male', 'Female'], # <--- เพิ่มบรรทัดนี้เพื่อกำหนดให้ Male ขึ้นก่อน
    kind='bar',
    palette=['#ff9999', '#66b3ff'],
    height=4,
    aspect=2.5
)

# --- Graph Details in English ---

# ตั้งชื่อแกนและหัวข้อย่อย
g.set_axis_labels("Year", "Positivity Rate (%)")
g.set_titles("Gender: {row_name}")

# ใส่ตัวเลข % กำกับบนแท่งกราฟ
for ax in g.axes.flat:
    for p in ax.patches:
        if p.get_height() > 0:
            ax.annotate(f'{p.get_height():.2f}%',
                        (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha='center', va='center',
                        xytext=(0, 9),
                        textcoords='offset points',
                        fontsize=9, fontweight='bold')

# ปรับระยะห่างด้านบนไม่ให้ชื่อกราฟหลักทับกับกราฟย่อย
plt.subplots_adjust(top=0.88)
g.fig.suptitle('Annual HIV Positivity Rate: KPs vs. Others by Gender', fontsize=16)

plt.show()

# %%
# 1. เตรียมข้อมูลจำนวนคน (Counts) แยกตามปี เพศ และกลุ่มประชากร
yearly_gender_summary = df.groupby(['year', 'sex']).sum().reset_index()

rows = []
for _, row in yearly_gender_summary.iterrows():
    gender = row['sex'].capitalize()
    year = row['year']

    # ข้อมูลกลุ่ม KPs
    rows.append({'Year': year, 'Gender': gender, 'Population': 'Key Populations (KPs)', 'Type': 'Tested', 'Count': row['test_all_kps']})
    rows.append({'Year': year, 'Gender': gender, 'Population': 'Key Populations (KPs)', 'Type': 'Positive', 'Count': row['positive_all_kps']})

    # ข้อมูลกลุ่ม Others
    rows.append({'Year': year, 'Gender': gender, 'Population': 'Others', 'Type': 'Tested', 'Count': row['test_others']})
    rows.append({'Year': year, 'Gender': gender, 'Population': 'Others', 'Type': 'Positive', 'Count': row['positive_others']})

plot_df = pd.DataFrame(rows)

# 2. สร้างกราฟแยกตามเพศ (Row) และกลุ่มประชากร (Col)
sns.set_theme(style="whitegrid")
g = sns.catplot(
    data=plot_df,
    x='Year',
    y='Count',
    hue='Type',
    row='Gender',
    col='Population',
    row_order=['Male', 'Female'],
    kind='bar',
    palette=['#add8e6', '#ff4d4d'], # สีฟ้าอ่อน (Tested) และ สีแดง (Positive)
    height=4,
    aspect=1.5,
    sharey=False # แยกสเกลแกน Y เพราะจำนวนคนตรวจกับคนติดอาจต่างกันมาก
)

# --- ปรับแต่งรายละเอียดกราฟ ---

g.set_axis_labels("Year", "Number of People")
g.set_titles("{row_name} | {col_name}")

# ใส่ตัวเลขจำนวนคนกำกับบนแท่งกราฟ
for ax in g.axes.flat:
    for p in ax.patches:
        if p.get_height() > 0:
            ax.annotate(f'{int(p.get_height()):,}',
                        (p.get_x() + p.get_width() / 2., p.get_height()),
                        ha='center', va='center',
                        xytext=(0, 9),
                        textcoords='offset points',
                        fontsize=8, fontweight='bold')

plt.subplots_adjust(top=0.9)
g.fig.suptitle('Annual HIV Testing: Number of Tested vs. Positive Cases', fontsize=16)

plt.show()

# %% [markdown]
# ---
# ## ข้อ 2: การระบุกลุ่มประชากรแฝง (Hidden KPs)
# เปรียบเทียบการกระจายตัวของผู้ติดเชื้อแยกตามเพศ ดูความผิดปกติในกลุ่ม "Other Female" เทียบกับ "KPs Male"

# %%
# 1. คำนวณผลรวมแยกตามเพศและกลุ่มประชากร
# สรุปข้อมูลหาค่าเฉลี่ยต่อปี (Mean) ตามที่คุณต้องการ
df_avg = df.groupby(['province', 'sex'])[['positive_all_kps', 'positive_others']].mean().reset_index()

# สรุปยอดรวมทั้งประเทศแยกตามเพศ
male_data = df_avg[df_avg['sex'] == 'male'][['positive_all_kps', 'positive_others']].sum()
female_data = df_avg[df_avg['sex'] == 'female'][['positive_all_kps', 'positive_others']].sum()

# 2. ตั้งค่าข้อมูลสำหรับกราฟ
labels = ['Key Populations (KPs)', 'Others']
colors = ['#ff9999','#66b3ff']
explode = (0.05, 0.05) # แยกชิ้นส่วนออกจากกันเล็กน้อย

# 3. สร้างกราฟ Donut Chart 2 วง (Male vs Female)
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 7))

# วงที่ 1: Male
ax1.pie(male_data, labels=labels, autopct='%1.1f%%', startangle=90,
        colors=colors, pctdistance=0.85, explode=explode)
center_circle1 = plt.Circle((0,0), 0.70, fc='white')
ax1.add_artist(center_circle1)
ax1.set_title("Gender: Male", fontsize=14, pad=20)

# วงที่ 2: Female
ax2.pie(female_data, labels=labels, autopct='%1.1f%%', startangle=90,
        colors=colors, pctdistance=0.85, explode=explode)
center_circle2 = plt.Circle((0,0), 0.70, fc='white')
ax2.add_artist(center_circle2)
ax2.set_title("Gender: Female", fontsize=14, pad=20)

# --- Graph Details in English ---
plt.suptitle('Proportion of HIV Positive Cases: KPs vs Others by Gender', fontsize=16, y=1.05)
plt.tight_layout()
plt.show()

# %%
# 1. รวมข้อมูลด้วยค่า Sum เพื่อหาค่าเฉลี่ยต่อปีของแต่ละจังหวัด
# ขั้นตอนนี้สำคัญมาก: จะทำให้ 1 จังหวัด มี 1 record ต่อ 1 เพศ (ป้องกันการนับซ้ำ 3 ปี)
df_avg = df.groupby(['province', 'sex'])[['positive_all_kps', 'positive_others']].sum().reset_index()

# 2. ปรับรูปแบบข้อมูลเป็น Long Format สำหรับ Seaborn
df_melted = df_avg.melt(
    id_vars=['province', 'sex'],
    value_vars=['positive_all_kps', 'positive_others'],
    var_name='Population_Group',
    value_name='Positive_Count'
)

# เปลี่ยนชื่อกลุ่มประชากรเป็นภาษาอังกฤษ
df_melted['Population_Group'] = df_melted['Population_Group'].replace({
    'positive_all_kps': 'Key Populations (KPs)',
    'positive_others': 'Others'
})

# 3. สร้างกราฟ Histogram พร้อม Log Scale
# log_scale=True จะช่วยกระจายข้อมูลที่กระจุกตัวอยู่ที่ 0-10 ให้ดูง่ายขึ้น
sns.set_theme(style="whitegrid")
g = sns.displot(
    data=df_melted,
    x='Positive_Count',
    hue='Population_Group',
    col='sex',
    kind='hist',
    kde=True,        # แสดงเส้นขอบเขตความหนาแน่น
    log_scale=True,  # ใช้มาตราส่วน Logarithm เพื่อขยายช่วงตัวเลขน้อยๆ
    palette='muted',
    height=6,
    aspect=1.2,
    bins=30
)

# --- ส่วนของการเปลี่ยนรายละเอียดกราฟเป็นภาษาอังกฤษ (Graph Details in English) ---

# ตั้งชื่อแกน X และ แกน Y
g.set_axis_labels("Average Annual Positive Cases (Log Scale)", "Count of Provinces")

# ตั้งชื่อหัวข้อกราฟย่อย
g.set_titles("Gender: {col_name}")

# ปรับตำแหน่งเพื่อใส่หัวข้อหลัก
plt.subplots_adjust(top=0.85)
g.fig.suptitle('Distribution of Provinces by Average Annual HIV Positive Cases', fontsize=16)

# แสดงผล
plt.show()

# %%
targat_features = ['positive_others',
                   'positive_fsw',
                   'positive_migrant',
                   'positive_msm',
                   'positive_partner_of_hiv',
                   'positive_prisoner',
                   'positive_pwid',
                   'positive_tg',
                   'positive_tgsw'
]

df_female = df[df['sex'] == 'female']
group = df_female.groupby('province')[targat_features].sum()
#group.info()


plt.figure(figsize=(8,6))
sns.heatmap(group.corr(), annot=True, fmt=".2f", cmap='coolwarm', center=0)
plt.title("Correlation Heatmap")
plt.show()

# %%
# 1. เตรียมข้อมูลเฉลี่ยรายจังหวัด (ใช้ df_avg ที่เราสร้างไว้ก่อนหน้า)
# เพิ่มกลุ่ม KPs อื่นๆ เข้ามาใน df_avg ด้วย
features = ['positive_others', 'positive_partner_of_hiv', 'positive_fsw', 'positive_prisoner', 'positive_pwid', 'positive_total']
df_latent = df_female.groupby('province')[features].sum().reset_index()

# 2. ปรับข้อมูลเป็น Long Format เพื่อให้วาดรูปเทียบกันได้ง่าย
df_melted = df_latent.melt(id_vars=['province', 'positive_total'],
                            value_vars=['positive_others', 'positive_partner_of_hiv', 'positive_fsw', 'positive_prisoner', 'positive_pwid'],
                            var_name='Population_Group', value_name='Cases')

# 3. สร้างกราฟ Scatter Plot เทียบกับ Total Cases (ขนาดของจังหวัด)
plt.figure(figsize=(12, 8))
sns.set_style("whitegrid")

# ใช้ Log Scale เพื่อให้เห็นจังหวัดเล็กและใหญ่ชัดเจน
g = sns.scatterplot(
    data=df_melted,
    x='positive_total',
    y='Cases',
    hue='Population_Group',
    alpha=0.6,
    s=100
)

plt.xscale('log')
plt.yscale('log')

plt.title('Evidence of Latent Variable: How Province Size Impacts All Groups', fontsize=15)
plt.xlabel('Total Positive Cases in Province (Log Scale) - Represents "Province Size"', fontsize=12)
plt.ylabel('Cases by Group (Log Scale)', fontsize=12)
plt.legend(title='Sub-groups', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## ข้อ 3: การเจาะลึกประสิทธิภาพการตรวจ (Yield in Other Female)
# ดูว่า Other Female มีอัตราการเจอเชื้อ (Yield) ต่ำหรือสูง หากสูงแปลว่าควรปรับปรุงการคัดกรองระบุตัวตนใหม่หรือไม่

# %% [markdown]
# ---
# ## ข้อ 4: การวิเคราะห์เชิงพื้นที่ (High Effort, Low Yield vs Low Effort, High Yield)
# วิเคราะห์ 2 แกนหลักคือจำนวนการตรวจ (Effort) และอัตราการตรวจเจอ (Yield) ในแต่ละพื้นที่

# %%
# 1. คำนวณยอดรวมรายภาค (เพื่อให้ได้ Weighted Average ที่ถูกต้อง)
df_region = df.groupby('region')[['test_total', 'positive_total']].sum().reset_index()

# 2. คำนวณ Yield Rate (%) รายภาค
df_region['yield_rate'] = (df_region['positive_total'] / df_region['test_total']) * 100

# 3. คำนวณค่าเฉลี่ย Yield Rate ทั้งประเทศ (Total Positive / Total Test)
avg_yield_national = (df_region['positive_total'].sum() / df_region['test_total'].sum()) * 100

# เรียงลำดับข้อมูลจากมากไปน้อย
df_region = df_region.sort_values('yield_rate', ascending=False)

plt.figure(figsize=(12, 7))
sns.set_theme(style="whitegrid")

# สร้าง Barplot โดยใช้ข้อมูลระดับภาค (df_region)
# ไม่ต้องใช้ estimator='mean' เพราะเราคำนวณค่าที่ถูกต้องมาให้แล้ว
ax = sns.barplot(
    data=df_region,
    x='yield_rate',
    y='region',
    palette='viridis'
)

# วาดเส้น Yield Rate เฉลี่ยทั้งประเทศ
plt.axvline(x=avg_yield_national, color='red', linestyle='--', linewidth=2,
            label=f'National Avg: {avg_yield_national:.2f}%')

# เพิ่มตัวเลขบนปลายแท่ง (เพื่อให้ดูง่ายขึ้น)
for p in ax.patches:
    ax.annotate(f'{p.get_width():.2f}%',
                (p.get_width() + 0.1, p.get_y() + p.get_height()/2),
                ha='left', va='center', fontsize=11)

plt.title('HIV Yield Rate by Region (Weighted Average)', fontsize=16)
plt.xlabel('Yield Rate (%)')
plt.ylabel('Region')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# /tmp/ipykernel_214/3486309910.py:18: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(

# %%
# @title ตัวอย่างการสร้าง table พร้อม conditional formatting
# 1. เตรียมข้อมูลตัวอย่าง
data = {
    'Region': ['East', 'East', 'East', 'Central', 'Central', 'Central', 'Central', 'Northeast', 'North', 'South'],
    'Province': ['Chonburi', 'Rayong', 'Prachinburi', 'Nakhon Pathom', 'Samut Prakan', 'Samut Songkhram', 'Sing Buri', 'Nakhon Phanom', 'Uttaradit', 'Krabi'],
    'Sum of test': [248848, 79634, 23505, 87644, 21781, 5019, 4090, 22099, 35645, 52293],
    'Sum of positive': [5038, 1610, 589, 1037, 2282, 117, 171, 373, 487, 393],
    'Sum of reach': [106643, 15255, 4, 33992, 6458, 0, 0, 191, 0, 701],
    'Sum of yield': [2.0, 2.0, 2.5, 1.2, 10.5, 2.3, 4.2, 1.7, 1.4, 0.8],
    'Sum of reach%': [42.9, 19.2, 0.0, 38.8, 29.6, 0.0, 0.0, 0.9, 0.0, 1.3]
}

df = pd.DataFrame(data)

# 2. รายชื่อจังหวัดที่ต้องการไฮไลท์สีเหลือง
yellow_provinces = ['Prachinburi', 'Samut Songkhram', 'Sing Buri', 'Nakhon Phanom', 'Uttaradit', 'Krabi']

# 3. ฟังก์ชันสำหรับไฮไลท์แถวสีเหลือง
def highlight_yellow(row):
    if row.Province in yellow_provinces:
        return ['background-color: #FFFF00'] * len(row)
    return [''] * len(row)

# 4. จัดรูปแบบตาราง (Styling)
styled_df = df.style\
    .bar(subset=['Sum of yield'], color='#FF9999', vmin=0, vmax=11)\
    .bar(subset=['Sum of reach%'], color='#A9D18E', vmin=0, vmax=100)\
    .format({
        'Sum of test': '{:,.0f}',
        'Sum of positive': '{:,.0f}',
        'Sum of reach': '{:,.0f}',
        'Sum of yield': '{:.1f}%',
        'Sum of reach%': '{:.1f}%'
    })\
    .set_properties(**{'text-align': 'center'}, subset=['Sum of yield', 'Sum of reach%'])

# แสดงผล (หากรันใน Jupyter Notebook จะเห็นสีทันที)
styled_df
# Out:
# <style type="text/css">
# #T_35382_row0_col5, #T_35382_row1_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #FF9999 18.2%, transparent 18.2%);
#   text-align: center;
# }
# #T_35382_row0_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #A9D18E 42.9%, transparent 42.9%);
#   text-align: center;
# }
# #T_35382_row1_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #A9D18E 19.2%, transparent 19.2%);
#   text-align: center;
# }
# #T_35382_row2_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #FF9999 22.7%, transparent 22.7%);
#   text-align: center;
# }
# #T_35382_row2_col6, #T_35382_row5_col6, #T_35382_row6_col6, #T_35382_row8_col6 {
#   width: 10em;
#   text-align: center;
# }
# #T_35382_row3_col5 {
#   width: 10em;
#   background: linear-gradient(90deg, #FF9999 10.9%, transparent 10.9%);
#   text-align: center;
# }
# #T_35382_row3_col6 {
#   width: 10em;
#   background: linear-gradient(90deg, #A9D18E 38.8%, transparent 38.8%);
# ...

# %% [markdown]
# ### เชิงพื้นที่

# %%
### 2.1 🌐 Testing Volume & Positivity Rate by Region
reg = df_long.groupby('region').agg(total_test=('test','sum'), total_positive=('positive','sum')).reset_index()
reg['rate'] = (reg['total_positive'] / reg['total_test']) * 100
reg = reg.sort_values('total_test', ascending=False)

fig, ax1 = plt.subplots(figsize=(12, 6))
x = np.arange(len(reg)); w = 0.4
ax1.bar(x, reg['total_test'], w, color='#4C9BE8', alpha=0.8, label='Total Tests')
ax1.set_xticks(x); ax1.set_xticklabels(reg['region'])
ax1.set_ylabel('Total Tests', color='#4C9BE8')
ax1.yaxis.set_major_formatter(plt.FuncFormatter(lambda v, _: f'{v/1e6:.1f}M'))
ax1.tick_params(axis='y', labelcolor='#4C9BE8')

ax2 = ax1.twinx()
ax2.plot(x, reg['rate'].values, color='#E8524C', marker='o', linewidth=3, markersize=10, label='Positivity Rate (%)')
for i, r in enumerate(reg['rate'].values):
    ax2.annotate(f'{r:.2f}%', xy=(i, r), textcoords='offset points', xytext=(0, 12), ha='center', fontsize=10, fontweight='bold', color='#E8524C')
ax2.set_ylabel('Positivity Rate (%)', color='#E8524C'); ax2.tick_params(axis='y', labelcolor='#E8524C'); ax2.grid(False)
plt.title('Regional Overview: Testing Volume vs. Positivity Rate')
fig.legend(loc='upper right', bbox_to_anchor=(0.88, 0.92), frameon=True)
fig.tight_layout(); plt.show()
print('📌 Big Picture: Which regions test the most? Which have the highest yields?')
# Out:
# 📌 Big Picture: Which regions test the most? Which have the highest yields?

# %%
### 2.2 🌐 Regional Positivity Rate Comparison
fig, ax = plt.subplots(figsize=(10, 5))
reg_sorted = reg.sort_values('rate', ascending=True)
colors = ['#E8524C' if r > reg['rate'].median() else '#4C9BE8' for r in reg_sorted['rate']]
ax.barh(reg_sorted['region'], reg_sorted['rate'], color=colors, alpha=0.85, edgecolor='white')
for i, (v, r) in enumerate(zip(reg_sorted['rate'], reg_sorted['region'])):
    ax.text(v + 0.02, i, f'{v:.2f}%', va='center', fontsize=11, fontweight='bold')
ax.set_xlabel('Positivity Rate (%)'); ax.set_title('Positivity Rate by Region (Red = Above Median)')
ax.axvline(reg['rate'].median(), color='gray', linestyle='--', alpha=0.6, label=f'Median: {reg["rate"].median():.2f}%')
ax.legend(); fig.tight_layout(); plt.show()
print('📌 Big Picture: Regions above median positivity rate may need more targeted resources.')
# Out:
# 📌 Big Picture: Regions above median positivity rate may need more targeted resources.

# %%
### 2.3 🔍 Province-Level Scatter: Tests vs. Positivity Rate
prov = df_long.groupby(['province', 'region']).agg(total_test=('test', 'sum'), total_positive=('positive', 'sum')).reset_index()
prov['positivity_rate'] = np.where(prov['total_test'] > 0, (prov['total_positive'] / prov['total_test']) * 100, 0.0)
top5 = prov.nlargest(5, 'positivity_rate')

fig, ax = plt.subplots(figsize=(14, 8))
regions = prov['region'].unique()
palette = sns.color_palette('Set2', n_colors=len(regions))
region_colors = dict(zip(regions, palette))

for region, color in region_colors.items():
    subset = prov[prov['region'] == region]
    ax.scatter(subset['total_test'], subset['positivity_rate'], label=region, color=color, s=80, edgecolors='white', linewidth=0.6, alpha=0.85, zorder=3)

for _, row in top5.iterrows():
    ax.annotate(row['province'], xy=(row['total_test'], row['positivity_rate']),
                textcoords='offset points', xytext=(8, 6), fontsize=9, fontweight='bold',
                arrowprops=dict(arrowstyle='->', color='gray', lw=0.8))

ax.set_xlabel('Total Tests Conducted'); ax.set_ylabel('Positivity Rate (%)')
ax.set_title('Province-Level: Testing Volume vs. Positivity Rate')
ax.legend(title='Region', bbox_to_anchor=(1.02, 1), loc='upper left', frameon=True)
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x/1e3:.0f}K'))
fig.tight_layout(); plt.show()
print('📌 Drill Down: Upper-left quadrant provinces = high yield, low testing → under-served.')
# Out:
# 📌 Drill Down: Upper-left quadrant provinces = high yield, low testing → under-served.

# %%
### 2.4 🔍 Top-10 Provinces by Positivity Rate
top10_rate = prov.nlargest(10, 'positivity_rate')
fig, ax = plt.subplots(figsize=(12, 6))
bars = ax.barh(top10_rate['province'], top10_rate['positivity_rate'], color='#E8524C', alpha=0.85, edgecolor='white')
for bar, v in zip(bars, top10_rate['positivity_rate']):
    ax.text(bar.get_width() + 0.05, bar.get_y() + bar.get_height()/2, f'{v:.2f}%', va='center', fontsize=10, fontweight='bold')
ax.set_xlabel('Positivity Rate (%)'); ax.set_title('Top-10 Provinces by Positivity Rate')
ax.invert_yaxis(); fig.tight_layout(); plt.show()
print('📌 Drill Down: These provinces have the highest screening yield — are they receiving enough resources?')
# Out:
# 📌 Drill Down: These provinces have the highest screening yield — are they receiving enough resources?

# %%
### 2.5 🔍 Top-10 Provinces by Testing Volume
top10_test = prov.nlargest(10, 'total_test')
fig, ax = plt.subplots(figsize=(12, 6))
bars = ax.barh(top10_test['province'], top10_test['total_test'], color='#4C9BE8', alpha=0.85, edgecolor='white')
for bar, v in zip(bars, top10_test['total_test']):
    ax.text(bar.get_width() + 500, bar.get_y() + bar.get_height()/2, f'{v:,.0f}', va='center', fontsize=10, fontweight='bold')
ax.set_xlabel('Total Tests'); ax.set_title('Top-10 Provinces by Testing Volume')
ax.xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x/1e3:.0f}K'))
ax.invert_yaxis(); fig.tight_layout(); plt.show()
print('📌 Drill Down: Highest-volume provinces — do they also have high positivity, or are they over-screening?')
# Out:
# 📌 Drill Down: Highest-volume provinces — do they also have high positivity, or are they over-screening?

# %%
### 2.6 🔍 Bottom-10 Provinces by Positivity Rate (Non-Zero)
prov_nz = prov[prov['positivity_rate'] > 0]
bottom10 = prov_nz.nsmallest(10, 'positivity_rate')
fig, ax = plt.subplots(figsize=(12, 6))
bars = ax.barh(bottom10['province'], bottom10['positivity_rate'], color='#A0C4E8', alpha=0.85, edgecolor='white')
for bar, v in zip(bars, bottom10['positivity_rate']):
    ax.text(bar.get_width() + 0.01, bar.get_y() + bar.get_height()/2, f'{v:.3f}%', va='center', fontsize=10, fontweight='bold')
ax.set_xlabel('Positivity Rate (%)'); ax.set_title('Bottom-10 Provinces by Positivity Rate (Lowest Yield)')
ax.invert_yaxis(); fig.tight_layout(); plt.show()
print('📌 Drill Down: These provinces may be over-screening low-risk populations.')
# Out:
# 📌 Drill Down: These provinces may be over-screening low-risk populations.

# %% [markdown]
# ---
# ## Part 4: Deep Dive 2 - Spatial Efficiency (Provincial Allocation)
#
# At the country level, resources are constrained. We must identify which provinces are operating efficiently and which are not. By plotting **Testing Effort (Volume) vs. Case Yield (Positivity Rate)**, we can group provinces into 4 actionable quadrants.
# \n

# %%
# Aggregate by Province
provincial_data = df_long.groupby('province')[['test', 'positive']].sum().reset_index()
provincial_data = provincial_data[provincial_data['test'] > 0]
provincial_data['yield_rate'] = (provincial_data['positive'] / provincial_data['test']) * 100

median_test = provincial_data['test'].median()
median_yield = provincial_data['yield_rate'].median()

def categorize_province(row):
    if row['test'] > median_test and row['yield_rate'] < median_yield:
        return 'High Effort, Low Yield (Review Efficiency)'
    elif row['test'] < median_test and row['yield_rate'] > median_yield:
        return 'Low Effort, High Yield (Scale Up Here)'
    elif row['test'] >= median_test and row['yield_rate'] >= median_yield:
        return 'High Effort, High Yield (Maintain)'
    else:
        return 'Low Effort, Low Yield (Watchlist)'

provincial_data['Quadrant'] = provincial_data.apply(categorize_province, axis=1)

plt.figure(figsize=(14, 9))
sns.scatterplot(
    data=provincial_data,
    x='test',
    y='yield_rate',
    hue='Quadrant',
    palette={
        'High Effort, Low Yield (Review Efficiency)': 'crimson',
        'Low Effort, High Yield (Scale Up Here)': 'forestgreen',
        'High Effort, High Yield (Maintain)': 'royalblue',
        'Low Effort, Low Yield (Watchlist)': 'silver'
    },
    s=150, alpha=0.8, edgecolor='black'
)

plt.axvline(median_test, color='gray', linestyle='--', linewidth=2, label=f'Median Tests: {median_test:,.0f}')
plt.axhline(median_yield, color='gray', linestyle='--', linewidth=2, label=f'Median Yield: {median_yield:.2f}%')

top_scale_up = provincial_data[provincial_data['Quadrant'] == 'Low Effort, High Yield (Scale Up Here)'].sort_values('yield_rate', ascending=False).head(4)
top_review = provincial_data[provincial_data['Quadrant'] == 'High Effort, Low Yield (Review Efficiency)'].sort_values('test', ascending=False).head(4)

for _, row in pd.concat([top_scale_up, top_review]).iterrows():
    plt.text(row['test'], row['yield_rate'] + 0.1, row['province'], fontsize=10, fontweight='bold', ha='center')

plt.xscale('log')
plt.title('Spatial Strategy: Provincial Testing Effort vs. Positivity Yield', fontsize=16, fontweight='bold')
plt.xlabel('Testing Volume [Log Scale] (Effort)', fontweight='bold')
plt.ylabel('Positivity Rate % (Yield)', fontweight='bold')
plt.legend(bbox_to_anchor=(1.02, 1), loc='upper left', fontsize=12)
plt.tight_layout()
plt.show()

print("📌 **Strategic Implication:**")
print("1. 🟢 Scale Up: Increase budgets and ACF tools in the Green Quadrant provinces. They have high yields and room to grow testing volume.")
print("2. 🔴 Review Efficiency: Investigate the Red Quadrant provinces. Despite massive testing, yields are exceptionally low—suggesting untargeted 'blind' screening.")
# Out:
# 📌 **Strategic Implication:**
# 1. 🟢 Scale Up: Increase budgets and ACF tools in the Green Quadrant provinces. They have high yields and room to grow testing volume.
# 2. 🔴 Review Efficiency: Investigate the Red Quadrant provinces. Despite massive testing, yields are exceptionally low—suggesting untargeted 'blind' screening.

# %% [markdown]
# ทำตารางเพิ่ม
# 1. จังหวัด Low effort, High yield สำหรับการวางแผนการ scale up (เรียงจาก positive สูง desc)
# 2. จังหวัด High effort, Low yield สำหรับการตรวจสอบความคุ้มค่าเพื่อทำการ reallocate resourse (เรียงจาก test สูง desc)
